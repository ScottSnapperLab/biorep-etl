# %% [markdown]
# # Set up

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

# %%
import sys
import os
from pathlib import Path
import math

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context(context="talk", font_scale=1, rc=None)
sns.set_style('whitegrid')

# %%
# Load the "autoreload" extension
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from pandas import IndexSlice as idx
import numpy as np

from collections import OrderedDict

from munch import Munch
from tqdm import tqdm

# %%
# import crunchers.sklearn_helpers.exploration as expl
# import crunchers.statsmodels_helpers.lazy_stats as stats
# import crunchers.pandas_helpers.transformations as xform

# %%
import biorep_etl.data.load_recode as loading

# %% [markdown]
# ## Constants

# %% [markdown]
# ### Get info for converting/moving this file to `reports`

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "IPYNB_NAME = " + "'"+thename+"'";
# kernel.execute(command);

# %%
# rv = Munch()

# rv.rep_id = 'yyy-mm-dd'
# rv.desc = 'blank'
# rv.ipnb = Path('{IPYNB_NAME}.ipynb'.format(IPYNB_NAME=IPYNB_NAME))
# rv.html = '{ipnb}.html'.format(ipnb=rv.ipnb.stem)
# rv.files = '{ipnb}_files'.format(ipnb=rv.ipnb.stem)
# rv.reprt_dir = '../../reports/{IPYNB_NAME}/'.format(IPYNB_NAME=IPYNB_NAME)

# %% [markdown]
# ### Other Constants

# %% [markdown]
# ## Paths

# %%
data_ = "../data/raw/SnapperGIBioreposito_DATA_2016-12-22_1633.csv"
labels_ = "../data/raw/SnapperGIBioreposito_DATA_LABELS_2016-12-22_1633.csv"

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Loading

# %%
data = loading.init_load_data_and_labels(data_=data_, labels_=labels_)

# %% [markdown]
# # Explore

# %%
def extract_lvl1(col):
    if '___' in col:
        return col.split('___')[0]
    else:
        return col

# %%
premidx = [[extract_lvl1(col), col] for col in data.data.columns.values]

# %%
list(zip(*premidx[:6]))
# Out:
# [('record_id',
#   'samplenumber',
#   'label_on_sample',
#   'mrn',
#   'biorepidnumber',
#   'completed_by'),
#  ('record_id',
#   'samplenumber',
#   'label_on_sample',
#   'mrn',
#   'biorepidnumber',
#   'completed_by')]

# %%
midx = pd.MultiIndex.from_arrays(list(zip(*premidx)), names=['a','b'])

# %%
columns_orig = data.data.columns

# %%
data.data.columns = midx
data.data.head()
# Out:
# a record_id  samplenumber label_on_sample      mrn biorepidnumber  \
# b record_id  samplenumber label_on_sample      mrn biorepidnumber
# 0         1  5.231301e+09            1004  2127951         1004.0
# 1         2  8.051400e+09        433.2-MX  2035198          433.2
# 2         3  8.161400e+09        433.2-NX  2035198          433.2
# 3         4  4.241300e+09               1  1042672            1.0
# 4         5  1.151300e+09               2  2237636            2.0
#
# a completed_by date_crf_completed sample_date registryconsent biorepconsent  \
# b completed_by date_crf_completed sample_date registryconsent biorepconsent
# 0          NaN                NaN  2012-12-25             0.0           1.0
# 1          NaN                NaN  2014-04-08             0.0           1.0
# 2          NaN                NaN  2014-07-11             0.0           1.0
# 3          NaN                NaN  2013-02-20             1.0           1.0
# 4          NaN                NaN  2012-03-10             1.0           1.0
#
# a                    ...                                  othermed date_labs  \
# b                    ...                                  othermed date_labs
# 0                    ...                                  Lo ovral       NaN
# 1                    ...                                       NaN       NaN
# 2                    ...                                       NaN       NaN
# 3                    ...                                       INH       NaN
# 4                    ...                      Ursodeoxycholic acid       NaN
#
# a   hct   wbc  plt   crp   esr  alb notes  \
# b   hct   wbc  plt   crp   esr  alb notes
# 0  37.5  8.32  288  0.47  13.0  4.3   NaN
# 1   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 2   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 3  31.4  2.83  233  0.09  19.0  4.3   NaN
# 4  40.2  6.42  310  0.29  13.0  4.7   NaN
#
# a ibd_biorepository_sample_database_complete
# b ibd_biorepository_sample_database_complete
# 0                                          2
# 1                                          2
# 2                                          2
# 3                                          2
# 4                                          2
#
# [5 rows x 203 columns]

# %%
data.data.T
# Out:
#                                                                                              0     \
# a                                          b
# record_id                                  record_id                                            1
# samplenumber                               samplenumber                                5.2313e+09
# label_on_sample                            label_on_sample                                   1004
# mrn                                        mrn                                            2127951
# biorepidnumber                             biorepidnumber                                    1004
# completed_by                               completed_by                                       NaN
# date_crf_completed                         date_crf_completed                                 NaN
# sample_date                                sample_date                                 2012-12-25
# registryconsent                            registryconsent                                      0
# biorepconsent                              biorepconsent                                        1
# prior_protocol_number                      prior_protocol_number                              NaN
# ibdyesno                                   ibdyesno                                             1
# ibdtype                                    ibdtype                                              2
# otheribddx                                 otheribddx                                         NaN
# family_history                             family_history                                       0
# familymember_ibd                           familymember_ibd___1                                 0
#                                            familymember_ibd___2                                 0
#                                            familymember_ibd___3                                 0
#                                            familymember_ibd___4                                 0
#                                            familymember_ibd___5                                 0
#                                            familymember_ibd___6                                 0
# other_relative                             other_relative                                     NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                               8
# other_immunodeficiency                     other_immunodeficiency                             NaN
# controldx                                  controldx                                          NaN
# other_diagnosis                            other_diagnosis                                    NaN
# control_immunodeficiency                   control_immunodeficiency                           NaN
# otherimmuno_control                        otherimmuno_control                                NaN
# psc                                        psc                                                NaN
# familymembertype                           familymembertype                                   NaN
# ...                                                                                           ...
# glucocorticoid_type                        glucocorticoid_type___4                              1
# current_immunomodulator                    current_immunomodulator                              0
# immunomodulator_type                       immunomodulator_type___1                             0
#                                            immunomodulator_type___2                             0
#                                            immunomodulator_type___3                             0
# current_antitnf                            current_antitnf                                      0
# antitnf_type                               antitnf_type___1                                     0
#                                            antitnf_type___2                                     0
#                                            antitnf_type___3                                     0
# current_calcineurin                        current_calcineurin                                  0
# calcineurin_type                           calcineurin_type___1                                 0
#                                            calcineurin_type___2                                 0
# current_otherbiologics                     current_otherbiologics                               0
# otherbiologic_type                         otherbiologic_type___1                               0
#                                            otherbiologic_type___2                               0
#                                            otherbiologic_type___3                               0
# fecaltransplant                            fecaltransplant                                      0
# current_othermeds                          current_othermeds                                    1
# othermed_type                              othermed_type___2                                    0
#                                            othermed_type___3                                    1
# othermed                                   othermed                                      Lo ovral
# date_labs                                  date_labs                                          NaN
# hct                                        hct                                               37.5
# wbc                                        wbc                                               8.32
# plt                                        plt                                                288
# crp                                        crp                                               0.47
# esr                                        esr                                                 13
# alb                                        alb                                                4.3
# notes                                      notes                                              NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete           2
#
#                                                                                              1     \
# a                                          b
# record_id                                  record_id                                            2
# samplenumber                               samplenumber                                8.0514e+09
# label_on_sample                            label_on_sample                               433.2-MX
# mrn                                        mrn                                            2035198
# biorepidnumber                             biorepidnumber                                   433.2
# completed_by                               completed_by                                       NaN
# date_crf_completed                         date_crf_completed                                 NaN
# sample_date                                sample_date                                 2014-04-08
# registryconsent                            registryconsent                                      0
# biorepconsent                              biorepconsent                                        1
# prior_protocol_number                      prior_protocol_number                              NaN
# ibdyesno                                   ibdyesno                                             3
# ibdtype                                    ibdtype                                            NaN
# otheribddx                                 otheribddx                                         NaN
# family_history                             family_history                                     NaN
# familymember_ibd                           familymember_ibd___1                                 0
#                                            familymember_ibd___2                                 0
#                                            familymember_ibd___3                                 0
#                                            familymember_ibd___4                                 0
#                                            familymember_ibd___5                                 0
#                                            familymember_ibd___6                                 0
# other_relative                             other_relative                                     NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                             NaN
# other_immunodeficiency                     other_immunodeficiency                             NaN
# controldx                                  controldx                                          NaN
# other_diagnosis                            other_diagnosis                                    NaN
# control_immunodeficiency                   control_immunodeficiency                           NaN
# otherimmuno_control                        otherimmuno_control                                NaN
# psc                                        psc                                                NaN
# familymembertype                           familymembertype                                     1
# ...                                                                                           ...
# glucocorticoid_type                        glucocorticoid_type___4                              0
# current_immunomodulator                    current_immunomodulator                            NaN
# immunomodulator_type                       immunomodulator_type___1                             0
#                                            immunomodulator_type___2                             0
#                                            immunomodulator_type___3                             0
# current_antitnf                            current_antitnf                                    NaN
# antitnf_type                               antitnf_type___1                                     0
#                                            antitnf_type___2                                     0
#                                            antitnf_type___3                                     0
# current_calcineurin                        current_calcineurin                                NaN
# calcineurin_type                           calcineurin_type___1                                 0
#                                            calcineurin_type___2                                 0
# current_otherbiologics                     current_otherbiologics                             NaN
# otherbiologic_type                         otherbiologic_type___1                               0
#                                            otherbiologic_type___2                               0
#                                            otherbiologic_type___3                               0
# fecaltransplant                            fecaltransplant                                    NaN
# current_othermeds                          current_othermeds                                  NaN
# othermed_type                              othermed_type___2                                    0
#                                            othermed_type___3                                    0
# othermed                                   othermed                                           NaN
# date_labs                                  date_labs                                          NaN
# hct                                        hct                                                NaN
# wbc                                        wbc                                                NaN
# plt                                        plt                                                NaN
# crp                                        crp                                                NaN
# esr                                        esr                                                NaN
# alb                                        alb                                                NaN
# notes                                      notes                                              NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete           2
#
#                                                                                              2     \
# a                                          b
# record_id                                  record_id                                            3
# samplenumber                               samplenumber                                8.1614e+09
# label_on_sample                            label_on_sample                               433.2-NX
# mrn                                        mrn                                            2035198
# biorepidnumber                             biorepidnumber                                   433.2
# completed_by                               completed_by                                       NaN
# date_crf_completed                         date_crf_completed                                 NaN
# sample_date                                sample_date                                 2014-07-11
# registryconsent                            registryconsent                                      0
# biorepconsent                              biorepconsent                                        1
# prior_protocol_number                      prior_protocol_number                              NaN
# ibdyesno                                   ibdyesno                                             3
# ibdtype                                    ibdtype                                            NaN
# otheribddx                                 otheribddx                                         NaN
# family_history                             family_history                                     NaN
# familymember_ibd                           familymember_ibd___1                                 0
#                                            familymember_ibd___2                                 0
#                                            familymember_ibd___3                                 0
#                                            familymember_ibd___4                                 0
#                                            familymember_ibd___5                                 0
#                                            familymember_ibd___6                                 0
# other_relative                             other_relative                                     NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                             NaN
# other_immunodeficiency                     other_immunodeficiency                             NaN
# controldx                                  controldx                                          NaN
# other_diagnosis                            other_diagnosis                                    NaN
# control_immunodeficiency                   control_immunodeficiency                           NaN
# otherimmuno_control                        otherimmuno_control                                NaN
# psc                                        psc                                                NaN
# familymembertype                           familymembertype                                     1
# ...                                                                                           ...
# glucocorticoid_type                        glucocorticoid_type___4                              0
# current_immunomodulator                    current_immunomodulator                            NaN
# immunomodulator_type                       immunomodulator_type___1                             0
#                                            immunomodulator_type___2                             0
#                                            immunomodulator_type___3                             0
# current_antitnf                            current_antitnf                                    NaN
# antitnf_type                               antitnf_type___1                                     0
#                                            antitnf_type___2                                     0
#                                            antitnf_type___3                                     0
# current_calcineurin                        current_calcineurin                                NaN
# calcineurin_type                           calcineurin_type___1                                 0
#                                            calcineurin_type___2                                 0
# current_otherbiologics                     current_otherbiologics                             NaN
# otherbiologic_type                         otherbiologic_type___1                               0
#                                            otherbiologic_type___2                               0
#                                            otherbiologic_type___3                               0
# fecaltransplant                            fecaltransplant                                    NaN
# current_othermeds                          current_othermeds                                  NaN
# othermed_type                              othermed_type___2                                    0
#                                            othermed_type___3                                    0
# othermed                                   othermed                                           NaN
# date_labs                                  date_labs                                          NaN
# hct                                        hct                                                NaN
# wbc                                        wbc                                                NaN
# plt                                        plt                                                NaN
# crp                                        crp                                                NaN
# esr                                        esr                                                NaN
# alb                                        alb                                                NaN
# notes                                      notes                                              NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete           2
#
#                                                                                              3     \
# a                                          b
# record_id                                  record_id                                            4
# samplenumber                               samplenumber                                4.2413e+09
# label_on_sample                            label_on_sample                                      1
# mrn                                        mrn                                            1042672
# biorepidnumber                             biorepidnumber                                       1
# completed_by                               completed_by                                       NaN
# date_crf_completed                         date_crf_completed                                 NaN
# sample_date                                sample_date                                 2013-02-20
# registryconsent                            registryconsent                                      1
# biorepconsent                              biorepconsent                                        1
# prior_protocol_number                      prior_protocol_number                              NaN
# ibdyesno                                   ibdyesno                                             1
# ibdtype                                    ibdtype                                              2
# otheribddx                                 otheribddx                                         NaN
# family_history                             family_history                                       1
# familymember_ibd                           familymember_ibd___1                                 0
#                                            familymember_ibd___2                                 0
#                                            familymember_ibd___3                                 0
#                                            familymember_ibd___4                                 0
#                                            familymember_ibd___5                                 1
#                                            familymember_ibd___6                                 0
# other_relative                             other_relative                                     NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                               8
# other_immunodeficiency                     other_immunodeficiency                             NaN
# controldx                                  controldx                                          NaN
# other_diagnosis                            other_diagnosis                                    NaN
# control_immunodeficiency                   control_immunodeficiency                           NaN
# otherimmuno_control                        otherimmuno_control                                NaN
# psc                                        psc                                                NaN
# familymembertype                           familymembertype                                   NaN
# ...                                                                                           ...
# glucocorticoid_type                        glucocorticoid_type___4                              0
# current_immunomodulator                    current_immunomodulator                              1
# immunomodulator_type                       immunomodulator_type___1                             1
#                                            immunomodulator_type___2                             0
#                                            immunomodulator_type___3                             0
# current_antitnf                            current_antitnf                                      0
# antitnf_type                               antitnf_type___1                                     0
#                                            antitnf_type___2                                     0
#                                            antitnf_type___3                                     0
# current_calcineurin                        current_calcineurin                                  0
# calcineurin_type                           calcineurin_type___1                                 0
#                                            calcineurin_type___2                                 0
# current_otherbiologics                     current_otherbiologics                               0
# otherbiologic_type                         otherbiologic_type___1                               0
#                                            otherbiologic_type___2                               0
#                                            otherbiologic_type___3                               0
# fecaltransplant                            fecaltransplant                                      0
# current_othermeds                          current_othermeds                                    1
# othermed_type                              othermed_type___2                                    0
#                                            othermed_type___3                                    1
# othermed                                   othermed                                           INH
# date_labs                                  date_labs                                          NaN
# hct                                        hct                                               31.4
# wbc                                        wbc                                               2.83
# plt                                        plt                                                233
# crp                                        crp                                               0.09
# esr                                        esr                                                 19
# alb                                        alb                                                4.3
# notes                                      notes                                              NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete           2
#
#                                                                                                        4     \
# a                                          b
# record_id                                  record_id                                                      5
# samplenumber                               samplenumber                                          1.1513e+09
# label_on_sample                            label_on_sample                                                2
# mrn                                        mrn                                                      2237636
# biorepidnumber                             biorepidnumber                                                 2
# completed_by                               completed_by                                                 NaN
# date_crf_completed                         date_crf_completed                                           NaN
# sample_date                                sample_date                                           2012-03-10
# registryconsent                            registryconsent                                                1
# biorepconsent                              biorepconsent                                                  1
# prior_protocol_number                      prior_protocol_number                                        NaN
# ibdyesno                                   ibdyesno                                                       1
# ibdtype                                    ibdtype                                                        2
# otheribddx                                 otheribddx                                                   NaN
# family_history                             family_history                                                 0
# familymember_ibd                           familymember_ibd___1                                           0
#                                            familymember_ibd___2                                           0
#                                            familymember_ibd___3                                           0
#                                            familymember_ibd___4                                           0
#                                            familymember_ibd___5                                           0
#                                            familymember_ibd___6                                           0
# other_relative                             other_relative                                               NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                                         8
# other_immunodeficiency                     other_immunodeficiency                                       NaN
# controldx                                  controldx                                                    NaN
# other_diagnosis                            other_diagnosis                                              NaN
# control_immunodeficiency                   control_immunodeficiency                                     NaN
# otherimmuno_control                        otherimmuno_control                                          NaN
# psc                                        psc                                                          NaN
# familymembertype                           familymembertype                                             NaN
# ...                                                                                                     ...
# glucocorticoid_type                        glucocorticoid_type___4                                        0
# current_immunomodulator                    current_immunomodulator                                        0
# immunomodulator_type                       immunomodulator_type___1                                       0
#                                            immunomodulator_type___2                                       0
#                                            immunomodulator_type___3                                       0
# current_antitnf                            current_antitnf                                                0
# antitnf_type                               antitnf_type___1                                               0
#                                            antitnf_type___2                                               0
#                                            antitnf_type___3                                               0
# current_calcineurin                        current_calcineurin                                            0
# calcineurin_type                           calcineurin_type___1                                           0
#                                            calcineurin_type___2                                           0
# current_otherbiologics                     current_otherbiologics                                         0
# otherbiologic_type                         otherbiologic_type___1                                         0
#                                            otherbiologic_type___2                                         0
#                                            otherbiologic_type___3                                         0
# fecaltransplant                            fecaltransplant                                                0
# current_othermeds                          current_othermeds                                              1
# othermed_type                              othermed_type___2                                              0
#                                            othermed_type___3                                              1
# othermed                                   othermed                                    Ursodeoxycholic acid
# date_labs                                  date_labs                                                    NaN
# hct                                        hct                                                         40.2
# wbc                                        wbc                                                         6.42
# plt                                        plt                                                          310
# crp                                        crp                                                         0.29
# esr                                        esr                                                           13
# alb                                        alb                                                          4.7
# notes                                      notes                                                        NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete                     2
#
#                                                                                              5     \
# a                                          b
# record_id                                  record_id                                            6
# samplenumber                               samplenumber                                7.0313e+09
# label_on_sample                            label_on_sample                                      3
# mrn                                        mrn                                            4243292
# biorepidnumber                             biorepidnumber                                       3
# completed_by                               completed_by                                       NaN
# date_crf_completed                         date_crf_completed                                 NaN
# sample_date                                sample_date                                 2013-02-01
# registryconsent                            registryconsent                                      1
# biorepconsent                              biorepconsent                                        1
# prior_protocol_number                      prior_protocol_number                              NaN
# ibdyesno                                   ibdyesno                                             1
# ibdtype                                    ibdtype                                              1
# otheribddx                                 otheribddx                                         NaN
# family_history                             family_history                                       1
# familymember_ibd                           familymember_ibd___1                                 0
#                                            familymember_ibd___2                                 0
#                                            familymember_ibd___3                                 0
#                                            familymember_ibd___4                                 0
#                                            familymember_ibd___5                                 1
#                                            familymember_ibd___6                                 0
# other_relative                             other_relative                                     NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                               8
# other_immunodeficiency                     other_immunodeficiency                             NaN
# controldx                                  controldx                                          NaN
# other_diagnosis                            other_diagnosis                                    NaN
# control_immunodeficiency                   control_immunodeficiency                           NaN
# otherimmuno_control                        otherimmuno_control                                NaN
# psc                                        psc                                                NaN
# familymembertype                           familymembertype                                   NaN
# ...                                                                                           ...
# glucocorticoid_type                        glucocorticoid_type___4                              0
# current_immunomodulator                    current_immunomodulator                              0
# immunomodulator_type                       immunomodulator_type___1                             0
#                                            immunomodulator_type___2                             0
#                                            immunomodulator_type___3                             0
# current_antitnf                            current_antitnf                                      1
# antitnf_type                               antitnf_type___1                                     1
#                                            antitnf_type___2                                     0
#                                            antitnf_type___3                                     0
# current_calcineurin                        current_calcineurin                                  0
# calcineurin_type                           calcineurin_type___1                                 0
#                                            calcineurin_type___2                                 0
# current_otherbiologics                     current_otherbiologics                               0
# otherbiologic_type                         otherbiologic_type___1                               0
#                                            otherbiologic_type___2                               0
#                                            otherbiologic_type___3                               0
# fecaltransplant                            fecaltransplant                                      0
# current_othermeds                          current_othermeds                                    1
# othermed_type                              othermed_type___2                                    0
#                                            othermed_type___3                                    1
# othermed                                   othermed                                    Folic Acid
# date_labs                                  date_labs                                          NaN
# hct                                        hct                                               38.9
# wbc                                        wbc                                               7.55
# plt                                        plt                                                360
# crp                                        crp                                               0.09
# esr                                        esr                                                NaN
# alb                                        alb                                                4.4
# notes                                      notes                                              NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete           2
#
#                                                                                               6     \
# a                                          b
# record_id                                  record_id                                             7
# samplenumber                               samplenumber                                1.11213e+10
# label_on_sample                            label_on_sample                                       4
# mrn                                        mrn                                             4300961
# biorepidnumber                             biorepidnumber                                        4
# completed_by                               completed_by                                        NaN
# date_crf_completed                         date_crf_completed                                  NaN
# sample_date                                sample_date                                  2013-08-13
# registryconsent                            registryconsent                                       1
# biorepconsent                              biorepconsent                                         1
# prior_protocol_number                      prior_protocol_number                               NaN
# ibdyesno                                   ibdyesno                                              1
# ibdtype                                    ibdtype                                               1
# otheribddx                                 otheribddx                                          NaN
# family_history                             family_history                                        1
# familymember_ibd                           familymember_ibd___1                                  0
#                                            familymember_ibd___2                                  0
#                                            familymember_ibd___3                                  0
#                                            familymember_ibd___4                                  0
#                                            familymember_ibd___5                                  1
#                                            familymember_ibd___6                                  0
# other_relative                             other_relative                                      NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                                8
# other_immunodeficiency                     other_immunodeficiency                              NaN
# controldx                                  controldx                                           NaN
# other_diagnosis                            other_diagnosis                                     NaN
# control_immunodeficiency                   control_immunodeficiency                            NaN
# otherimmuno_control                        otherimmuno_control                                 NaN
# psc                                        psc                                                 NaN
# familymembertype                           familymembertype                                    NaN
# ...                                                                                            ...
# glucocorticoid_type                        glucocorticoid_type___4                               0
# current_immunomodulator                    current_immunomodulator                               1
# immunomodulator_type                       immunomodulator_type___1                              0
#                                            immunomodulator_type___2                              1
#                                            immunomodulator_type___3                              0
# current_antitnf                            current_antitnf                                       0
# antitnf_type                               antitnf_type___1                                      0
#                                            antitnf_type___2                                      0
#                                            antitnf_type___3                                      0
# current_calcineurin                        current_calcineurin                                   0
# calcineurin_type                           calcineurin_type___1                                  0
#                                            calcineurin_type___2                                  0
# current_otherbiologics                     current_otherbiologics                                0
# otherbiologic_type                         otherbiologic_type___1                                0
#                                            otherbiologic_type___2                                0
#                                            otherbiologic_type___3                                0
# fecaltransplant                            fecaltransplant                                       0
# current_othermeds                          current_othermeds                                     1
# othermed_type                              othermed_type___2                                     0
#                                            othermed_type___3                                     1
# othermed                                   othermed                                       Ursodiol
# date_labs                                  date_labs                                           NaN
# hct                                        hct                                                41.8
# wbc                                        wbc                                                4.61
# plt                                        plt                                                 212
# crp                                        crp                                                0.13
# esr                                        esr                                                  11
# alb                                        alb                                                 4.3
# notes                                      notes                                               NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete            2
#
#                                                                                               7     \
# a                                          b
# record_id                                  record_id                                             8
# samplenumber                               samplenumber                                1.11213e+10
# label_on_sample                            label_on_sample                                       4
# mrn                                        mrn                                             4300961
# biorepidnumber                             biorepidnumber                                        4
# completed_by                               completed_by                                        NaN
# date_crf_completed                         date_crf_completed                                  NaN
# sample_date                                sample_date                                  2013-06-19
# registryconsent                            registryconsent                                       1
# biorepconsent                              biorepconsent                                         1
# prior_protocol_number                      prior_protocol_number                               NaN
# ibdyesno                                   ibdyesno                                              1
# ibdtype                                    ibdtype                                               1
# otheribddx                                 otheribddx                                          NaN
# family_history                             family_history                                        1
# familymember_ibd                           familymember_ibd___1                                  0
#                                            familymember_ibd___2                                  0
#                                            familymember_ibd___3                                  0
#                                            familymember_ibd___4                                  0
#                                            familymember_ibd___5                                  1
#                                            familymember_ibd___6                                  0
# other_relative                             other_relative                                      NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                                8
# other_immunodeficiency                     other_immunodeficiency                              NaN
# controldx                                  controldx                                           NaN
# ...
#
#                                                                                                                                 2802  \
# a                                          b
# record_id                                  record_id                                                                            2833
# samplenumber                               samplenumber                                                                   8.2316e+09
# label_on_sample                            label_on_sample                                                                      1919
# mrn                                        mrn                                                                               4559381
# biorepidnumber                             biorepidnumber                                                                       1919
# completed_by                               completed_by                                                                            2
# date_crf_completed                         date_crf_completed                                                             2016-08-21
# sample_date                                sample_date                                                                    2016-04-24
# registryconsent                            registryconsent                                                                         1
# biorepconsent                              biorepconsent                                                                           1
# prior_protocol_number                      prior_protocol_number                                                                 NaN
# ibdyesno                                   ibdyesno                                                                                1
# ibdtype                                    ibdtype                                                                                 2
# otheribddx                                 otheribddx                                                                            NaN
# family_history                             family_history                                                                          0
# familymember_ibd                           familymember_ibd___1                                                                    0
#                                            familymember_ibd___2                                                                    0
#                                            familymember_ibd___3                                                                    0
#                                            familymember_ibd___4                                                                    0
#                                            familymember_ibd___5                                                                    0
#                                            familymember_ibd___6                                                                    0
# other_relative                             other_relative                                                                        NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                                                                  8
# other_immunodeficiency                     other_immunodeficiency                                                                NaN
# controldx                                  controldx                                                                             NaN
# other_diagnosis                            other_diagnosis                                                                       NaN
# control_immunodeficiency                   control_immunodeficiency                                                              NaN
# otherimmuno_control                        otherimmuno_control                                                                   NaN
# psc                                        psc                                                                                     0
# familymembertype                           familymembertype                                                                      NaN
# ...                                                                                                                              ...
# glucocorticoid_type                        glucocorticoid_type___4                                                                 1
# current_immunomodulator                    current_immunomodulator                                                                 0
# immunomodulator_type                       immunomodulator_type___1                                                                0
#                                            immunomodulator_type___2                                                                0
#                                            immunomodulator_type___3                                                                0
# current_antitnf                            current_antitnf                                                                       NaN
# antitnf_type                               antitnf_type___1                                                                        0
#                                            antitnf_type___2                                                                        0
#                                            antitnf_type___3                                                                        0
# current_calcineurin                        current_calcineurin                                                                     1
# calcineurin_type                           calcineurin_type___1                                                                    0
#                                            calcineurin_type___2                                                                    1
# current_otherbiologics                     current_otherbiologics                                                                  1
# otherbiologic_type                         otherbiologic_type___1                                                                  0
#                                            otherbiologic_type___2                                                                  0
#                                            otherbiologic_type___3                                                                  1
# fecaltransplant                            fecaltransplant                                                                         0
# current_othermeds                          current_othermeds                                                                       1
# othermed_type                              othermed_type___2                                                                       0
#                                            othermed_type___3                                                                       1
# othermed                                   othermed                                    omeprazole, acetaminofen, odnasetron, naloxon
# date_labs                                  date_labs                                                                      2016-04-23
# hct                                        hct                                                                                  28.2
# wbc                                        wbc                                                                                 23.59
# plt                                        plt                                                                                   491
# crp                                        crp                                                                                   NaN
# esr                                        esr                                                                                   NaN
# alb                                        alb                                                                                   NaN
# notes                                      notes                                                                                 NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete                                              2
#
#                                                                                                               2803
# a                                          b
# record_id                                  record_id                                                          2834
# samplenumber                               samplenumber                                                1.13016e+10
# label_on_sample                            label_on_sample                                                    1748
# mrn                                        mrn                                                             2106899
# biorepidnumber                             biorepidnumber                                                     1748
# completed_by                               completed_by                                                          3
# date_crf_completed                         date_crf_completed                                           2016-07-21
# sample_date                                sample_date                                                  2016-06-30
# registryconsent                            registryconsent                                                       0
# biorepconsent                              biorepconsent                                                         1
# prior_protocol_number                      prior_protocol_number                                               NaN
# ibdyesno                                   ibdyesno                                                              1
# ibdtype                                    ibdtype                                                               2
# otheribddx                                 otheribddx                                                          NaN
# family_history                             family_history                                                        0
# familymember_ibd                           familymember_ibd___1                                                  0
#                                            familymember_ibd___2                                                  0
#                                            familymember_ibd___3                                                  0
#                                            familymember_ibd___4                                                  0
#                                            familymember_ibd___5                                                  0
#                                            familymember_ibd___6                                                  0
# other_relative                             other_relative                                                      NaN
# ibd_immunodeficiencies                     ibd_immunodeficiencies                                                8
# other_immunodeficiency                     other_immunodeficiency                                              NaN
# controldx                                  controldx                                                           NaN
# other_diagnosis                            other_diagnosis                                                     NaN
# control_immunodeficiency                   control_immunodeficiency                                            NaN
# otherimmuno_control                        otherimmuno_control                                                 NaN
# psc                                        psc                                                                   0
# familymembertype                           familymembertype                                                    NaN
# ...                                                                                                            ...
# glucocorticoid_type                        glucocorticoid_type___4                                               0
# current_immunomodulator                    current_immunomodulator                                               0
# immunomodulator_type                       immunomodulator_type___1                                              0
#                                            immunomodulator_type___2                                              0
#                                            immunomodulator_type___3                                              0
# current_antitnf                            current_antitnf                                                       0
# antitnf_type                               antitnf_type___1                                                      0
#                                            antitnf_type___2                                                      0
#                                            antitnf_type___3                                                      0
# current_calcineurin                        current_calcineurin                                                   0
# calcineurin_type                           calcineurin_type___1                                                  0
#                                            calcineurin_type___2                                                  0
# current_otherbiologics                     current_otherbiologics                                                0
# otherbiologic_type                         otherbiologic_type___1                                                0
#                                            otherbiologic_type___2                                                0
#                                            otherbiologic_type___3                                                0
# fecaltransplant                            fecaltransplant                                                       0
# current_othermeds                          current_othermeds                                                     1
# othermed_type                              othermed_type___2                                                     0
#                                            othermed_type___3                                                     1
# othermed                                   othermed                                    diphenhydramine, omeprazole
# date_labs                                  date_labs                                                    2016-06-29
# hct                                        hct                                                                46.4
# wbc                                        wbc                                                                6.16
# plt                                        plt                                                                 280
# crp                                        crp                                                                 NaN
# esr                                        esr                                                                 NaN
# alb                                        alb                                                                 NaN
# notes                                      notes                                                               NaN
# ibd_biorepository_sample_database_complete ibd_biorepository_sample_database_complete                            2
#
# [203 rows x 2804 columns]

# %%
def make_midx(df):
    pass
#      lvl1 =

# %% [markdown]
# # Convert to HTML report and move to reports folder

# %%
# rv.reprt_dir

# %%
# !jupyter nbconvert --to html_toc $rv.ipnb

# %%
# !mkdir -p $rv.reprt_dir
## !mv -f $rv.html $rv.files $rv.reprt_dir
